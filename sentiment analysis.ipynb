# %%
# !pip install torch transformers datasets evaluate
# Out:
# Requirement already satisfied: torch in g:\new folder\lib\site-packages (2.4.0)
# Requirement already satisfied: transformers in g:\new folder\lib\site-packages (4.43.3)
# Requirement already satisfied: datasets in g:\new folder\lib\site-packages (2.20.0)
# Collecting evaluate
#   Obtaining dependency information for evaluate from https://files.pythonhosted.org/packages/c2/d6/ff9baefc8fc679dcd9eb21b29da3ef10c81aa36be630a7ae78e4611588e1/evaluate-0.4.2-py3-none-any.whl.metadata
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: filelock in g:\new folder\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in g:\new folder\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in g:\new folder\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in g:\new folder\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in g:\new folder\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in g:\new folder\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in g:\new folder\lib\site-packages (from transformers) (0.24.3)
# Requirement already satisfied: numpy>=1.17 in g:\new folder\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in g:\new folder\lib\site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in g:\new folder\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in g:\new folder\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in g:\new folder\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in g:\new folder\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in g:\new folder\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in g:\new folder\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in g:\new folder\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in g:\new folder\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in g:\new folder\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in g:\new folder\lib\site-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in g:\new folder\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in g:\new folder\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in g:\new folder\lib\site-packages (from datasets) (3.8.3)
# Requirement already satisfied: attrs>=17.3.0 in g:\new folder\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in g:\new folder\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in g:\new folder\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in g:\new folder\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in g:\new folder\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in g:\new folder\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in g:\new folder\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: idna<4,>=2.5 in g:\new folder\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in g:\new folder\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in g:\new folder\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: colorama in g:\new folder\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\new folder\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in g:\new folder\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in g:\new folder\lib\site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: mpmath>=0.19 in g:\new folder\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in g:\new folder\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.1 kB ? eta -:--:--
#    --------- ------------------------------ 20.5/84.1 kB 640.0 kB/s eta 0:00:01
#    -------------- ------------------------- 30.7/84.1 kB 435.7 kB/s eta 0:00:01
#    ------------------------ --------------- 51.2/84.1 kB 327.7 kB/s eta 0:00:01
#    ---------------------------------------- 84.1/84.1 kB 429.6 kB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.2

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in g:\new folder\lib\site-packages (2.4.0)
# Requirement already satisfied: torchvision in g:\new folder\lib\site-packages (0.19.0)
# Requirement already satisfied: torchaudio in g:\new folder\lib\site-packages (2.4.0)
# Requirement already satisfied: filelock in g:\new folder\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in g:\new folder\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in g:\new folder\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in g:\new folder\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in g:\new folder\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in g:\new folder\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: numpy<2 in g:\new folder\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in g:\new folder\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\new folder\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in g:\new folder\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import transformers
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import datasets
from datasets import load_dataset, DatasetDict
import evaluate
import numpy as np

# Ensure correct versions
print(f"Using torch version: {torch.__version__}")
print(f"Using transformers version: {transformers.__version__}")

try:
    # Load the dataset
    dataset = load_dataset('imdb')

    # Load the BERT tokenizer
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    print("Tokenizer loaded successfully.")
    
    # Tokenize the dataset
    def tokenize_function(examples):
        return tokenizer(examples['text'], padding='max_length', truncation=True)
    
    tokenized_datasets = dataset.map(tokenize_function, batched=True)

    # Split the dataset into training and validation sets
    train_test_valid = tokenized_datasets['train'].train_test_split(test_size=0.1)
    train_valid_test = DatasetDict({
        'train': train_test_valid['train'],
        'validation': train_test_valid['test']
    })
    
    # Load the BERT model for sequence classification
    model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)
    print("Model loaded successfully.")
    
    # Define training arguments
    training_args = TrainingArguments(
        output_dir='./results',
        eval_strategy='epoch',  # Updated here
        learning_rate=2e-5,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        num_train_epochs=3,
        weight_decay=0.01,
    )
    
    # Define the evaluation metric using the new evaluate library
    metric = evaluate.load('accuracy', trust_remote_code=True)
    
    def compute_metrics(eval_pred):
        logits, labels = eval_pred
        predictions = np.argmax(logits, axis=-1)
        return metric.compute(predictions=predictions, references=labels)
    
    # Initialize the Trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_valid_test['train'],
        eval_dataset=train_valid_test['validation'],
        compute_metrics=compute_metrics,
    )
    
    # Train the model
    trainer.train()
    
    # Evaluate the model
    eval_result = trainer.evaluate()
    print(f"Accuracy: {eval_result['eval_accuracy']:.4f}")
    
    # Perform inference
    def predict(text):
        inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=512)
        outputs = model(**inputs)
        prediction = torch.argmax(outputs.logits, dim=-1).item()
        return 'positive' if prediction == 1 else 'negative'
    
    # Example usage
    texts = [
        "I love this product! It has changed my life for the better.",
        "This is the worst thing I have ever bought. Completely useless.",
        "Had an amazing experience with their customer service.",
        "The product is okay, not too bad but not great either."
    ]
    
    for text in texts:
        sentiment = predict(text)
        print(f"Text: {text}\nSentiment: {sentiment}\n")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import torch
#       2 import transformers
#       3 from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
#
# File G:\New folder\Lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "G:\New folder\Lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.
